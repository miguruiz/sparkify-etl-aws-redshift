# %%
# %load_ext sql

# %%
import configparser
import psycopg2

config = configparser.ConfigParser()
config.read('../dwh.cfg')

ENDPOINT           = config.get("OTHER","ENDPOINT")
DB                 = config.get("CLUSTER","DB_NAME")
DB_USER            = config.get("CLUSTER","DB_USER")
DB_PASSWORD        = config.get("CLUSTER","DB_PASSWORD")
PORT               = config.get("CLUSTER","DB_PORT")
ZONE               = config.get("PARAMS","ZONE")

LOG_DATA           = config.get("S3","LOG_DATA")
LOG_JSONPATH       = config.get("S3","LOG_JSONPATH")
SONG_DATA          = config.get("S3","SONG_DATA")
ANR                = config.get("OTHER","ARN")

# %%
conn_string=f"postgresql://{DB_USER}:{DB_PASSWORD}@{ENDPOINT}:{PORT}/{DB}"
# %sql $conn_string

# %%
# %%sql
#
# Select s.title, a.listend_times
# FROM (SELECT song_id, count(song_id) as  listend_times
#     FROM songplays p
#     GROUP BY song_id
#     ORDER BY 2 desc
#     LIMIT 1) a
# LEFT JOIN songs s
# ON a.song_id = s.song_id
# Out:
#  * postgresql://ucaityuser:***@udacitycluster.crqztkqnczh2.us-west-2.redshift.amazonaws.com:5439/musicserver
# 1 rows affected.
# [("You're The One", 37)]

# %%
    user_id INT sortkey,
    first_name TEXT,
    last_name TEXT,
    gender VARCHAR(1),
    level TEXT NOT NULL

# %%
# %%sql
#
# Select b.user_id, u.first_name ||  u.last_name as name, b.activity
# FROM (SELECT user_id, count(user_id) as activity
#         FROM songplays
#         GROUP BY user_id
#         ORDER BY 2 desc
#         LIMIT 10) b
# LEFT JOIN users u
# ON u.user_id = b.user_id
# Out:
#  * postgresql://ucaityuser:***@udacitycluster.crqztkqnczh2.us-west-2.redshift.amazonaws.com:5439/musicserver
# 16 rows affected.
# [(80, 'TeganLevine', 740),
#  (88, 'MohammadRodriguez', 312),
#  (80, 'TeganLevine', 740),
#  (88, 'MohammadRodriguez', 312),
#  (44, 'AleenaKirby', 439),
#  (36, 'MatthewJones', 280),
#  (36, 'MatthewJones', 280),
#  (49, 'ChloeCuevas', 772),
#  (49, 'ChloeCuevas', 772),
#  (73, 'JacobKlein', 305),
#  (15, 'LilyKoch', 495),
#  (15, 'LilyKoch', 495),
#  (24, 'LaylaGriffin', 349),
#  (29, 'JacquelineLynch', 381),
#  (29, 'JacquelineLynch', 381),
#  (97, 'KateHarrell', 595)]

# %%
# %%sql
# SELECT artist_id, count(artist_id) as artist_count
# FROM artists
# group by 1
# where artist_count
# Out:
#  * postgresql://ucaityuser:***@udacitycluster.crqztkqnczh2.us-west-2.redshift.amazonaws.com:5439/musicserver
# 9553 rows affected.
# [('ARTE9CG1187B99B1AF', 4),
#  ('AR065TW1187FB4C3A5', 4),
#  ('ARCBD0U1187FB466EF', 4),
#  ('ARZ5H0P1187B98A1DD', 4),
#  ('ARMD3XX1187B9ACF84', 4),
#  ('ARV481W1187FB38CD9', 4),
#  ('ARS26BQ1187B99466D', 4),
#  ('AR4OH581187B9B7157', 3),
#  ('AR3THYK1187B999F1F', 3),
#  ('ARPBTRI1187FB52457', 3),
#  ('AR5Z97E1187FB36169', 3),
#  ('ARJGAUD1187FB505DA', 3),
#  ('ARTOG9T1187B99074E', 3),
#  ('ARJXVM01187B98EED1', 3),
#  ('ARA5TTT1187FB3AC2C', 3),
#  ('AROETUE1187FB4A677', 3),
#  ('AR1OGXT1187B9893EB', 3),
#  ('ARTDQRC1187FB4EFD4', 3),
#  ('AR0CANF1187B9AF35F', 3),
#  ('ARBCUNV1187B98A9FB', 3),
#  ('ARF2SVO1187FB53E8F', 3),
#  ('AR5LTOU1187B98CAD9', 3),
#  ('ARXA17J1187FB3B507', 3),
#  ('ARMB95F1187B9B5B93', 3),
#  ('ARNQESK11F4C83FD6F', 3),
#  ('ARKTSTP1187FB51C66', 3),
#  ('ARKC83D1187B9AB367', 3),
#  ('ART62WC1187FB47E80', 3),
# ...

# %%
# SELECT user_id, date, topup_value, rank
# FROM ( SELECT user_id,
#        date,
#        topup_value,
#        rank() OVER (PARTITION BY user_id ORDER BY topup_value DESC) AS rank
# FROM topups) AS ranked_topups
# WHERE rank <= 3
# ORDER BY user_id, rank;

    userid, 
    firstName, 
    lastName, 
    gender, 
    level,

# %%
    artist_id TEXT UNIQUE NOT NULL sortkey,
    name TEXT NOT NULL,
    location TEXT,
    lattitude TEXT,
    longitude TEXT

# %%
# %%sql
# Select  artist_id,
#         artist_name,
#         artist_location,
#         artist_latitude,
#         artist_longitude,
# FROM (
#     SELECT
#         artist_id,
#         artist_name,
#         artist_location,
#         artist_latitude,
#         artist_longitude,
#         rank() OVER (PARTITION BY artist_id, year ORDER BY year DESC) AS rank
#     FROM songs_staging
# )
# WHERE rank = 1
# Out:
#  * postgresql://ucaityuser:***@udacitycluster.crqztkqnczh2.us-west-2.redshift.amazonaws.com:5439/musicserver
# 98 rows affected.
# [(5, 'Elijah', 'Davis', 'M', 'free', 1),
#  (8, 'Kaylee', 'Summers', 'F', 'free', 1),
#  (10, 'Sylvie', 'Cruz', 'F', 'free', 1),
#  (12, 'Austin', 'Rosales', 'M', 'free', 1),
#  (18, 'Jacob', 'Rogers', 'M', 'free', 1),
#  (21, 'Preston', 'Sanders', 'M', 'free', 1),
#  (33, 'Bronson', 'Harris', 'M', 'free', 1),
#  (68, 'Jordan', 'Rodriguez', 'F', 'free', 1),
#  (72, 'Hayden', 'Brock', 'F', 'paid', 1),
#  (76, 'Jayden', 'Duffy', 'F', 'free', 1),
#  (80, 'Tegan', 'Levine', 'F', 'paid', 1),
#  (81, 'Sienna', 'Colon', 'F', 'free', 1),
#  (86, 'Aiden', 'Hess', 'M', 'free', 1),
#  (2, 'Jizelle', 'Benjamin', 'F', 'free', 1),
#  (27, 'Carlos', 'Carter', 'M', 'free', 1),
#  (34, 'Evelin', 'Ayala', 'F', 'free', 1),
#  (41, 'Brayden', 'Clark', 'M', 'free', 1),
#  (55, 'Martin', 'Johnson', 'M', 'free', 1),
#  (60, 'Devin', 'Larson', 'M', 'free', 1),
# ...

# %%
# %%sql
#  SELECT
#         artist_id,
#         artist_name,
#         artist_location,
#         artist_latitude,
#         artist_longitude,
#         rank() OVER (PARTITION BY artist_id, year ORDER BY year DESC) AS rank
#     FROM songs_staging
# Out:
#  * postgresql://ucaityuser:***@udacitycluster.crqztkqnczh2.us-west-2.redshift.amazonaws.com:5439/musicserver
